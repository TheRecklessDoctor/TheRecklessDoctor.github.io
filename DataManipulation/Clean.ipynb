# %%
# import required libraries
import pandas as pd

# %%
# import dataset
data = pd.read_csv("../data/world_population.csv")
data.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
GR_ds = data[["Country","Continent","Growth Rate"]]
GR_ds.head()
# Out:
#           Country Continent  Growth Rate
# 0     Afghanistan      Asia       1.0257
# 1         Albania    Europe       0.9957
# 2         Algeria    Africa       1.0164
# 3  American Samoa   Oceania       0.9831
# 4         Andorra    Europe       1.0100

# %%
sorted_GR = GR_ds.sort_values(by=["Growth Rate"],ascending=False)
sorted_GR.head()
# Out:
#       Country Continent  Growth Rate
# 133   Moldova    Europe       1.0691
# 164    Poland    Europe       1.0404
# 148     Niger    Africa       1.0378
# 202     Syria      Asia       1.0376
# 189  Slovakia    Europe       1.0359

# %%
#export to csv file
sorted_GR.iloc[:11,:].to_csv("../data/Top10Growth_Rate.csv")

# %%
#create new dataset for population changes over the years
copy1 = data.copy(deep=True)

copy1["change2022_1970"] = copy1["2022 Population"] - copy1["1970 Population"]

copy1.to_csv("../data/change.csv")

# %%
# dataset for line chart

ds_copy = data.copy(deep=True)
grouped = ds_copy.groupby("Continent").mean()
grouped
# Out:
# /var/folders/3v/smc24lcd439c520zdn9htkr80000gn/T/ipykernel_2730/2697936538.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = ds_copy.groupby("Continent").mean()
#                      Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa          92.157895     2.503037e+07     2.387144e+07     2.107197e+07
# Asia            77.560000     9.442767e+07     9.326173e+07     8.916500e+07
# Europe         124.500000     1.486295e+07     1.491584e+07     1.483071e+07
# North America  160.925000     1.500740e+07     1.485591e+07     1.425960e+07
# Oceania        188.521739     1.958198e+06     1.910149e+06     1.756664e+06
# South America   97.571429     3.120119e+07     3.082357e+07     2.950960e+07
#
# ...

# %%
grouped.melt(id_vars=["Continent"], var_name="Date",value_name="Value")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 grouped.melt(id_vars=["Continent"], var_name="Date",value_name="Value")
#
# File ~/opt/anaconda3/envs/DS_personal/lib/python3.10/site-packages/pandas/core/frame.py:9117, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9106 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9107 def melt(
#    9108     self,
#    (...)
#    9114     ignore_index: bool = True,
#    9115 ) -> DataFrame:
# -> 9117     return melt(
#    9118         self,
#    9119         id_vars=id_vars,
#    9120         value_vars=value_vars,
#    9121         var_name=var_name,
#    9122         value_name=value_name,
#    9123         col_level=col_level,
#    9124         ignore_index=ignore_index,
#    9125     ).__finalize__(self, method="melt")
#
# ...
